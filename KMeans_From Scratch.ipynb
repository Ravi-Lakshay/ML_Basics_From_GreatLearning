# %% [markdown]
# # K Means Clustering Algorithm | K Means Example in Python | Machine Learning Algorithms | Edureka

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # https://www.jeremyjordan.me/grouping-data-points-with-k-means-clustering/#:~:text=K%2Dmeans%20clustering%20is%20a,in%20k%20groups%2C%20or%20clusters.&text=Reassign%20centroid%20value%20to%20be,stay%20in%20the%20same%20cluster.
