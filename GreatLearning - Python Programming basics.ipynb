# %%
var1 = "bob"
var1
# Out:
# 'bob'

# %%
# relational operators

# %%
a=10 
b=20
#a<b
a==b
#a!=b
# Out:
# False

# %%
# logical operators

# %%
a & b
# Out:
# 0

# %%
a = True
b= False
a & b
# Out:
# False

# %%
a | b
# Out:
# True

# %%
# python strings

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a1 = "Joey doesn't share pizza"

# %%
a1[0]
# Out:
# 'J'

# %%
a1[-1] # the last character in the string
# Out:
# 'a'

# %%
a1[5:12] # 5 is inclusive and 12 is exclusive
# Out:
# "doesn't"

# %%
a1.upper()
# Out:
# "JOEY DOESN'T SHARE PIZZA"

# %%
a1.title()
# Out:
# "Joey Doesn'T Share Pizza"

# %% [markdown]
# Some non primitive data structues in python:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tup1 = (1,"a", True, "b", 23.0) #heterogenous data types

# %%
tup1
# Out:
# (1, 'a', True, 'b', 23.0)

# %%
tup1[1:4]
# Out:
# ('a', True, 'b')

# %%
tup1[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-e1834aa6a247> in <module>()
# ----> 1 tup1[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
l1 = [1, "a", True]

# %%
l1
# Out:
# [1, 'a', True]

# %%
l1[0:1]
# Out:
# [1]

# %%
l1[0]=100
l1
# Out:
# [100, 'a', True]

# %%
l1.append("sword")
l1
# Out:
# [100, 'a', True, 'sword']

# %%
l1.append([1,2,3,4])
l1
# Out:
# [100, 'a', True, 'sword', [1, 2, 3, 4]]

# %%
l1.pop()
l1
# Out:
# [100, 'a', True, 'sword']

# %% [markdown]
# Dictionary with - key & value pairs
#
# ![image.png](attachment:image.png)

# %%
d1 = {"mango":45, "apple":30, "orange":77, "guava":125}
d1
# Out:
# {'mango': 45, 'apple': 30, 'orange': 77, 'guava': 125}

# %%
d1.keys()
# Out:
# dict_keys(['mango', 'apple', 'orange', 'guava'])

# %%
d1.values()
# Out:
# dict_values([45, 30, 77, 125])

# %%
d1["mango"]=100
d1
# Out:
# {'mango': 100, 'apple': 30, 'orange': 77, 'guava': 125}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s1 = {1, a, "a", 3, 78}
s1
# Out:
# {1, 3, 78, 'a'}

# %%
s1.add("hello world")
s1
# Out:
# {1, 3, 78, 'a', 'hello world'}

# %%
s1.update(["sadsa", 123, 4+3j])
s1
# Out:
# {(4+3j), 1, 123, 3, 78, 'a', 'hello world', 'sadsa'}

# %% [markdown]
# #                                  .                            Flow control statements:

# %%
i1=0;
while i1<5:
    print(i1)
    i1=i1+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
color = ["green", "blue", "pink"]
item = ["chair", "book", "phone"]
i1=1
for i1 in color:
    print(i1,i2)
    i1=0
    for i2 in item:
        print(i1,i2)
# Out:
# green phone
# 0 chair
# 0 book
# 0 phone
# blue phone
# 0 chair
# 0 book
# 0 phone
# pink phone
# 0 chair
# 0 book
# 0 phone

# %% [markdown]
# #                                                      Functions

# %%
def hellp():
    print("hello sparta")

# %%
hellp()
# Out:
# hello sparta

# %%
def odd_even(sd):
    if sd%2==0:
        print(sd,"is even")
    else:
            print(sd, "is odd")

# %%
odd_even(98)
# Out:
# 98 is even

# %% [markdown]
# ![image.png](attachment:image.png)
#
# If we want to use all these real world objects in programming paradigm, here we use OOP

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Phone: #name of the class- first letter CAPITAL
    #inside this properties and behaviour of the class
    
    def make_call(self): # name of this methods is make_call, and self here means that this methods to the instance which invokes it
        print("Makin a phone call")
    def play_game(sef):
        print("Playing game")

# %%
p1 = Phone() #Here created instance of this Phone class

# %%
p1.play_game()
# Out:
# Playing game

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Phone:
    
    def add_color(self,color):
        self.color = color
    
    def add_cost(self,cost):
        self.cost=cost
        
    def show_color(self):
        return self.color
    
    def show_cost(self):
        return self.cost
    
    def make_call(self):
        print("Making a phone call")
        
    def play_game(self):
        print("Playing game")

# %%
p2 = Phone()

# %%
p2.add_color("blue")
p2.add_cost(10000)

# %%
p2.show_color()
p2.show_cost()
# Out:
# 10000

# %%
print(p2.show_color())
p2.show_cost()
# Out:
# blue
# 10000

# %%
p3=Phone() # Here creating another instance!

# %%
p3.add_color("red")
p3.add_cost(20000)

p3.show_color()
# Out:
# 'red'

# %% [markdown]
# Another important concept in OOP is inheretance!
#
# ![image.png](attachment:image.png)

# %%
class Iphone(Phone):
    # Now this will have one extra method which is cure_cancer
    
    def cure_cancer(self):
        print("I can cure cancer")

# %%
ip1 = Iphone()

# %%
ip1.add_color("Grey")
ip1.add_cost(50000)
ip1.cure_cancer()
# Out:
# I can cure cancer

# %%
ip1.show_cost()
# Out:
# 50000

# %% [markdown]
#                               We now work with some packages in pythos:

# %% [markdown]
# ![image.png](attachment:image.png)
